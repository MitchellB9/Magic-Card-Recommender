# %%
import pandas as pd
import numpy as np
import re
import pickle
import spacy
from spacy import displacy
import nltk
from nltk.util import ngrams
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import MWETokenizer
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances
from sklearn.decomposition import NMF
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mitch\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# load dataset

card_text = pd.read_json('oracle-cards-20220819210331.json')

# %%
# drop 69 unnecessary columns

drop_cols = ['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'mtgo_foil_id', 'tcgplayer_id','cardmarket_id', 'lang', 
             'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'colors',
             'legalities', 'games', 'reserved', 'foil', 'nonfoil', 'finishes', 'oversized', 'promo', 'reprint', 'variation',
             'set_id', 'set', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri',
             'collector_number', 'digital', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
             'full_art', 'textless', 'booster', 'story_spotlight', 'prices', 'related_uris', 'security_stamp', 'preview',
             'power', 'toughness', 'penny_rank', 'arena_id', 'watermark', 'produced_mana', 'all_parts', 'card_faces',
             'frame_effects', 'tcgplayer_etched_id', 'promo_types', 'loyalty', 'life_modifier', 'hand_modifier',
             'color_indicator', 'content_warning', 'cmc', 'keywords', 'flavor_text', 'edhrec_rank']

card_text = card_text.drop(columns = drop_cols)

# %%
# clean

# fill NaNs
card_text['oracle_text'] = card_text['oracle_text'].fillna('None')

# drop useless rows
vangard_mask = ((card_text['set_type'] == 'vanguard') |
                (card_text['type_line'] == 'Vanguard') |
                (card_text['set_name'].str.contains('Vanguard')))
card_text.drop(card_text[vangard_mask].index, inplace = True)
card_text.drop(card_text[card_text['type_line'].str.contains('Emblem')].index, inplace = True)
card_text.reset_index(drop = True, inplace = True)

# emliminate extraneous characters
unwanted_text = "[.,!?()•—\\:;|]"
card_text['oracle_text'] = card_text['oracle_text'].map(lambda x: re.sub(unwanted_text, '', x))

# remove all references of a card's name from it's rules text
card_text['Rules_Text'] = card_text[['name', 'oracle_text']].apply(lambda x: 
                                                                     x['oracle_text'].replace(x['name'], 'This_Card')
                                                                     if x['name'] in x['oracle_text']
                                                                     else x['oracle_text'],
                                                                     axis = 1)

# set rules_text to lower case
card_text['Rules_Text'] = card_text['Rules_Text'].str.lower()

# # create new dataframe with which to work
# ct = card_text['Rules_Text'].to_frame()

# %%
# # initialize whitespace tokenizer
# whitespace_tokenizer = RegexpTokenizer("\s+", gaps = True)

# # make new column for whitespace tokenizer
# ct['no_space_tokens'] = ct['Rules_Text'].apply(lambda x: whitespace_tokenizer.tokenize(x))

# %%
# # load english library with spacy
# nlp = spacy.load('en_core_web_sm')

# # set function to get spacy tokens
# def spacy_on_list(x):
#     spacy_list = [nlp(element) for element in x]
#     return spacy_list

# # make new column for spacy tokens
# ct['spacy_tokens'] = ct['no_space_tokens'].apply(lambda x: spacy_on_list(x))

# %%
# save ct
# with open('ct_df', 'wb') as f:
#     pickle.dump(ct,f)
    
# load ct
with open('ct_df', 'rb') as f:
    ct = pickle.load(f)

# %%
# dummy fucntion to pass to custom_tfidf
def dummy_function(doc):
    return doc

# # save spacy tokens as list
# docs = ct['spacy_tokens'].to_list()

# # save spacy tokens as series
# doc_series = pd.Series(docs)

# %%
# set function to get lemmetized non-stop-words
def lemmy_no_stop(x):
    core_text = []
    for tuple_ in x:
        for token in tuple_:
            core_text.append(token.lemma_)  
    #core_text = [[token.lemma_ for token in tuple_ if token.is_stop == False] for tuple_ in x]  
    core_text = [ele for ele in core_text if ele != []]
    return core_text

# apply fucntion to create new column in ct
ct['core_text'] = ct['spacy_tokens'].apply(lambda x: lemmy_no_stop(x))

# convert that column to a list
core_docs = ct['core_text'].to_list()

# %%
custom_tfidf_2gram = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), tokenizer=dummy_function,
                                     preprocessor=dummy_function, token_pattern=None)
CX_2gram = custom_tfidf_2gram.fit_transform(core_docs).toarray()

# %%
# CX_2gram = StandardScaler().fit_transform(CX_2gram)
CX_2gram.shape
# Out:
# (26182, 30891)

# %%
pca = PCA(n_components = 1500)
pca.fit(CX_2gram)
# pca.explained_variance_ratio_

def evr (array):
    _sum = 0
    for element in array:
        _sum += element
    return _sum

evr(pca.explained_variance_ratio_)
# Out:
# 0.7664875211305309

# %%
CX_2gram = pca.transform(CX_2gram)
np_CX = np.array(CX_2gram)
non_neg_CX_2gram = np_CX + 1

# %%
nmf_2gram = NMF(20)
nmf_2gram = nmf_2gram.fit(non_neg_CX_2gram)
docs_topics_2gram = nmf_2gram.transform(non_neg_CX_2gram)
topics_terms_2gram = nmf_2gram.components_
# Out:
# C:\Users\mitch\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\mitch\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"

# %%
nmf_2gram_df = pd.DataFrame(docs_topics_2gram, columns = ['Topic_0', 'Topic_1', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5',
                                                          'Topic_6', 'Topic_7', 'Topic_8', 'Topic_9', 'Topic_10', 'Topic_11',
                                                          'Topic_12', 'Topic_13', 'Topic_14', 'Topic_15', 'Topic_16',
                                                          'Topic_17', 'Topic_18', 'Topic_19'])

# %%
results_df = card_text[['name', 'Rules_Text', 'color_identity', 'mana_cost', 'type_line', 'rarity', 'set_name',
                                'set_type']]
topics = nmf_2gram_df.merge(results_df, left_index=True, right_index=True)

# %%
droppers = ['Topic_0', 'Topic_1', 'Topic_2', 'Topic_3', 'Topic_4', 'Topic_5', 'Topic_6', 'Topic_7', 'Topic_8',
            'Topic_9', 'Topic_19', 'Topic_11', 'Topic_12', 'Topic_13', 'Topic_14', 'Topic_15', 'Topic_16', 'Topic_17',
            'Topic_18']

target_topic = 'Topic_10'

# top10 = top10.sort_values(by = 'distances', ascending = True).head(10).reset_index(drop=True)
topic_mask = topics[target_topic] != 0
pd.set_option('display.max_colwidth', None)
topics[topic_mask].drop(columns = droppers, axis = 1).sort_values(by = target_topic, ascending = False).head(20)
# Out:
#        Topic_10                   name  \
# 509    0.077704  Ecologist's Terrarium
# 24751  0.074251        Wander in Death
# 3970   0.073729      Beneath the Sands
# 14648  0.070079         Expedition Map
# 9867   0.069198      Wirewood Guardian
# 752    0.068978        Yoked Plowbeast
# 12777  0.068978        Sandbar Merfolk
# 8711   0.068978           Ridge Rannet
# 13463  0.068978        Barkhide Mauler
# 4906   0.068978        Sandbar Serpent
# 19343  0.068705         Ominous Parcel
# 11393  0.068641              Energizer
# 18339  0.068534      Braidwood Sextant
# 25212  0.068097       Embermage Goblin
# 21037  0.067054    Miraculous Recovery
# 14107  0.066782              Flame Jet
# 22566  0.066521            Spike Drone
# 22362  0.065979         Migration Path
# 8293   0.065902                 Sicken
# 23388  0.065240         Grave Upheaval
#
#                                                                                                                                                                                                                                  Rules_Text  \
# 509     when this_card enters the battlefield you may search your library for a basic land card reveal it put it into your hand then shuffle\n{2} {t} sacrifice this_card put a +1/+1 counter on target creature activate only as a sorcery
# 24751                                                                                                                return up to two target creature cards from your graveyard to your hand\ncycling {2} {2} discard this card draw a card
# 3970                                                                                               search your library for a basic land card put it onto the battlefield tapped then shuffle\ncycling {2} {2} discard this card draw a card
# 14648                                                                                                                          {2} {t} sacrifice this_card search your library for a land card reveal it put it into your hand then shuffle
# 9867                                                                                                             forestcycling {2} {2} discard this card search your library for a forest card reveal it put it into your hand then shuffle
# 752                                                                                                                                                                                           cycling {2} {2} discard this card draw a card
# 12777                                                                                                                                                                                         cycling {2} {2} discard this card draw a card
# 8711                                                                                                                                                                                          cycling {2} {2} discard this card draw a card
# 13463                                                                                                                                                                                         cycling {2} {2} discard this card draw a card
# 4906                                                                                                                                                                                          cycling {2} {2} discard this card draw a card
# 19343                                                  {2} {t} sacrifice this_card search your library for a basic land card reveal it put it into your hand then shuffle\n{5} {t} sacrifice this_card it deals 4 damage to target creature
# 11393                                                                                                                                                                                              {2} {t} put a +1/+1 counter on this_card
# 18339                                                                                                             {2} {t} sacrifice this_card search your library for a basic land card reveal that card put it into your hand then shuffle
# 25212                                                 when this_card enters the battlefield you may search your library for a card named this_card reveal it put it into your hand then shuffle\n{t} this_card deals 1 damage to any target
# 21037                                                                                                                                          return target creature card from your graveyard to the battlefield put a +1/+1 counter on it
# 14107                                                                                                                              this_card deals 3 damage to target player or planeswalker\ncycling {2} {2} discard this card draw a card
# 22566                                                                                         this_card enters the battlefield with a +1/+1 counter on it\n{2} remove a +1/+1 counter from this_card put a +1/+1 counter on target creature
# 22362                                                                                   search your library for up to two basic land cards put them onto the battlefield tapped then shuffle\ncycling {2} {2} discard this card draw a card
# 8293                                                                                                                                         enchant creature\nenchanted creature gets -1/-1\ncycling {2} {2} discard this card draw a card
# 23388  put target creature card from a graveyard onto the battlefield under your control it gains haste\nbasic landcycling {2} {2} discard this card search your library for a basic land card reveal it put it into your hand then shuffle
#
#       color_identity  mana_cost                       type_line    rarity  \
# 509               []        {2}                        Artifact    common
# 24751            [B]     {2}{B}                         Sorcery    common
# 3970             [G]     {2}{G}                         Sorcery    common
# 14648             []        {1}                        Artifact    common
# 9867             [G]  {5}{G}{G}           Creature — Elf Mutant    common
# 752              [W]  {5}{W}{W}                Creature — Beast    common
# 12777            [U]        {U}              Creature — Merfolk    common
# 8711             [R]  {5}{R}{R}                Creature — Beast    common
# 13463            [G]     {4}{G}                Creature — Beast    common
# 4906             [U]     {4}{U}              Creature — Serpent  uncommon
# 19343             []        {1}                        Artifact    common
# 11393             []        {4}  Artifact Creature — Juggernaut      rare
# 18339             []        {1}                        Artifact  uncommon
# 25212            [R]     {3}{R}        Creature — Goblin Wizard  uncommon
# 21037            [W]     {4}{W}                         Instant  uncommon
# 14107            [R]     {1}{R}                         Sorcery    common
# 22566            [G]        {G}          Creature — Spike Drone    common
# 22362            [G]     {3}{G}                         Sorcery  uncommon
# 8293             [B]        {B}              Enchantment — Aura    common
# 23388         [B, R]  {4}{B}{R}                         Sorcery  uncommon
#
#                      set_name   set_type
# 509    Kamigawa: Neon Dynasty  expansion
# 24751                Amonkhet  expansion
# 3970      Hour of Devastation  expansion
# 14648          Double Masters    masters
# 9867                  Scourge  expansion
# 752           Shards of Alara  expansion
# 12777             Urza's Saga  expansion
# 8711          Shards of Alara  expansion
# 13463               Onslaught  expansion
# 4906              Urza's Saga  expansion
# 19343  Streets of New Capenna  expansion
# 11393                 Tempest  expansion
# 18339          Urza's Destiny  expansion
# 25212               Onslaught  expansion
# 21037        Ultimate Masters    masters
# 14107          Urza's Destiny  expansion
# 22566                 Tempest  expansion
# 22362   New Capenna Commander  commander
# 8293              Urza's Saga  expansion
# 23388          Commander 2016  commander

# %%
# 0: **garbage**
# 1: tap for mana
# 2: +1/+1 till end of turn
# 3: ETB
# 4: look at top cards of library
# 5: enchant creature
# 6: **garbage**
# 7: enchant creature
# 8: **garbage**
# 9: reanimate
# 10: **garbage**
# 11: upkeep trigger
# 12: face down
# 13: stuff you control
# 14: prevent damage
# 15: bounce
# 16: tutor
# 17: prevent damage
# 18: cost reduction
# 19: discard/draw

# %%
# create new dataframe for results

# card_name = "Kess, Dissident Mage"
card_name = "Merfolk Looter"

index = card_text.index[card_text['name'] == card_name]
distances = pairwise_distances(docs_topics_2gram[index].reshape(1,-1), docs_topics_2gram, metric='cosine')

# results_df.insert(loc = 0, column = 'distances', value = pd.Series(distances[0]))

top10 = results_df[results_df['name'] != card_name]
top10['Rules_Text'] = top10['Rules_Text'].str.replace('\n', ', ')
card_text['oracle_text'] = card_text['oracle_text'].str.replace('\n', ', ')
top10 = top10.sort_values(by = 'distances', ascending = True).head(10).reset_index(drop=True)

# output results
print(f"Chosen Card:\t{card_text['name'].iloc[index[0]]}")
print(f"Mana Cost:\t{card_text['mana_cost'].iloc[index[0]]}")
print(f"Type:\t\t{card_text['type_line'].iloc[index[0]]}")
print(f"Text:\t\t{card_text['oracle_text'].iloc[index[0]]}\n{'*'*60}\n{'*'*60}")
for i in range(10):
    print(f"{i+1}.")
#     print(f"Similarity:\t{top10['distances'].values[i]}")
    print(f"Similarity:\t{round((1-top10['distances'].values[i]), 4)*100}%")
    print(f"Name:\t\t{top10['name'].values[i]}")
    print(f"Mana Cost:\t{top10['mana_cost'].values[i]}")
    print(f"Type:\t\t{top10['type_line'].values[i]}")
    print(f"Text:\t\t{top10['Rules_Text'].values[i]}\n{'-'*60}")
# Out:
# C:\Users\mitch\AppData\Local\Temp/ipykernel_21772/2129643876.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10['Rules_Text'] = top10['Rules_Text'].str.replace('\n', ', ')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21772/2129643876.py in <module>
#      12 top10['Rules_Text'] = top10['Rules_Text'].str.replace('\n', ', ')
#      13 card_text['oracle_text'] = card_text['oracle_text'].str.replace('\n', ', ')
# ---> 14 top10 = top10.sort_values(by = 'distances', ascending = True).head(10).reset_index(drop=True)
#      15
#      16 # output results
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'distances'

# %%
# Less than perfect matches for: Kess, Dissident Mage

# Fury of the Horde
# Into the Fray
# Dead Revels
# Omniscience

# %%
# nmf_2gram_10_df = pd.DataFrame(docs_topics_2gram, columns = ['ETB',
#                                                              'until_end_of_turn',
#                                                              'burn',
#                                                              'scry_effect',
#                                                              '+1/+1_counters',
#                                                              'unblockable',
#                                                              'reanimation',
#                                                              'upkeep_trigger',
#                                                              'card_advantage',
#                                                              'enchant_creature',
#                                                              'face_down',
#                                                              'mana_ability',
#                                                              'buff_creatures',
#                                                              'prevent_damage',
#                                                              'tutor',
#                                                              'sacrifice_cost',
#                                                              'destroy_target',
#                                                              'stats_equal_to_X',
#                                                              'bounce',
#                                                              'lifegain'])

# %%
# incorporate topic ratio per output
# find size of each topic
# streamlit
